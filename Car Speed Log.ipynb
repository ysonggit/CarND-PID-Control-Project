# %%
import matplotlib.pyplot as plt
import csv


c = []
y = []
x = []

with open('build/car_param.log','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    i = 0
    for row in plots:
        i+= 1
        x.append(i)
        c.append(float(row[0])) # cte
        y.append(float(row[1])) # steering angle

plt.plot(x,y, label='steering angle')
plt.plot(x,c, label="CTE")
plt.xlabel('x')
plt.ylabel('y')
plt.title('Car Params')
#plt.legend(['', 'y = 2x', 'y = 3x', 'y = 4x'], loc='upper left')
plt.show()

# %%
def plotSteeringCte(fname, start=0, end=100000):
    c = []
    y = []
    x = []

    with open(fname,'r') as csvfile:
        plots = csv.reader(csvfile, delimiter=',')
        i = 0
        for row in plots:
            i+= 1
            x.append(i)
            c.append(float(row[0])) # cte
            y.append(float(row[1])) # steering angle

    end_idx = min(end, len(x))
    plt.plot(x[start:end_idx],y[start:end_idx], label='steering angle')
    plt.plot(x[start:end_idx],c[start:end_idx], label="CTE")
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Car Params')
    plt.legend(['steering angle', 'CTE'], loc='upper left')
    plt.show()
    
plotSteeringCte('build/car_param.log', 3000,4500)

# %%
plotSteeringCte('build/car_param.log.20-01-2019-12-52-27')

# %%
plotSteeringCte('build/car_param.log.20-01-2019-12-58-31')
